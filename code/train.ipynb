# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pip install ultralytics
from ultralytics import YOLO

# %%
# Load a pretrained YOLO model (recommended for training)
path = '/content/drive/MyDrive/Colab Notebooks/yolo/yolov8n.pt'
model = YOLO(path)

# %%
print(type(model))
# Out:
# <class 'ultralytics.models.yolo.model.YOLO'>

# %%
import torch
USE_GPU = True
if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# %%
print('using device:', device)
# Out:
# using device: cuda

# %%
model = model.to(device=device)

# %%
# Train the model using the 'UECFOOD256' dataset for 20 epochs
#results = model.train(data='/content/drive/MyDrive/Colab Notebooks/NutritionExperts/config.yaml', epochs=20, lr0=0.01,
                      #lrf=0.01, weight_decay=0.03)
! yolo task = detect mode = train model=yolov8n.pt data='/content/drive/MyDrive/Colab Notebooks/NutritionExperts/config.yaml', epochs=10, lr0=0.01, lrf=0.01, weight_decay=0.03
# Out:
# WARNING ⚠️ 'data=/content/drive/MyDrive/Colab Notebooks/NutritionExperts/config.yaml,' does not require trailing comma ',', updating to 'data=/content/drive/MyDrive/Colab Notebooks/NutritionExperts/config.yaml'.
# WARNING ⚠️ 'epochs=10,' does not require trailing comma ',', updating to 'epochs=10'.
# WARNING ⚠️ 'lr0=0.01,' does not require trailing comma ',', updating to 'lr0=0.01'.
# WARNING ⚠️ 'lrf=0.01,' does not require trailing comma ',', updating to 'lrf=0.01'.
# Ultralytics YOLOv8.0.147 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
