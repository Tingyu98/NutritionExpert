# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -q streamlit
import streamlit as st
# !npm install localtunnel
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 51.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 17.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 20.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 89.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 32.6 MB/s eta 0:00:00
# ...
# npm WARN saveError ENOENT: no such file or directory, open '/content/package.json'
# npm notice created a lockfile as package-lock.json. You should commit this file.
# npm WARN enoent ENOENT: no such file or directory, open '/content/package.json'
# npm WARN content No description
# npm WARN content No repository field.
# npm WARN content No README data
# ...

# %%
# Setting page layout
st.set_page_config(
    page_title="NutritionExpert",  # Setting page title
    page_icon="🍴"
)

# %%
# Creating main page heading
st.title("NutritionExpert")
# Out:
# 2023-08-05 14:18:56.534
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.10/dist-packages/ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator()

# %%
st.markdown(
    '''
    ### 1. Meal Analysis \n
    **Task:** Performs object detection on an uploaded meal image and provides per serving nutritional facts for each detected food category \n
    **Machine Learning Model:** [YOLOv8](https://github.com/ultralytics/ultralytics) trained on [UECFOOD-256](http://foodcam.mobi/dataset256.html) and [School Lunch](http://foodcam.mobi/dataset.html) Datasets \n
    **API:** [CalorieNinjas](https://calorieninjas.com/api) \n

    ### 2. Diet Planning \n
    **Task:** Outputs a personalized diet plan according to body metrics, diet preferences, and fitness goals \n
    **Machine Learning Model:** [GPT-4](https://openai.com/gpt-4) with prompt engineering \n
    **API:** [OpenAI API](https://openai.com/blog/openai-api)
    ''')
# Out:
# DeltaGenerator()

# %%
# !streamlit run Home.py &>/content/logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 35.245.111.106
# npx: installed 22 in 3.282s
# your url is: https://late-cities-obey.loca.lt

# %%
# !npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 35.245.111.106
